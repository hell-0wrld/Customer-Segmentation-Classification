# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gc

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 1. 회원정보

# %%
df1 = pd.read_parquet('../open/train/1.회원정보/201807_train_회원정보.parquet')
df2 = pd.read_parquet('../open/train/1.회원정보/201808_train_회원정보.parquet')
df3 = pd.read_parquet('../open/train/1.회원정보/201809_train_회원정보.parquet')
df4 = pd.read_parquet('../open/train/1.회원정보/201810_train_회원정보.parquet')
df5 = pd.read_parquet('../open/train/1.회원정보/201811_train_회원정보.parquet')
df6 = pd.read_parquet('../open/train/1.회원정보/201812_train_회원정보.parquet')


# 담을 리스트 리스트
all_df = []

# df1~6 담아주기
all_df.append(df1)
all_df.append(df2)
all_df.append(df3)
all_df.append(df4)
all_df.append(df5)
all_df.append(df6)

# merge
merged_df = pd.concat(all_df, ignore_index=True)

print("\n--- 데이터 기본 정보 ---")
merged_df.info()
print("\n")
merged_df.head()
# Out:
# --- 데이터 기본 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 78 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   기준년월                int64
#  1   ID                  object
#  2   남녀구분코드              int64
#  3   연령                  object
#  4   Segment             object
#  5   회원여부_이용가능           int64
#  6   회원여부_이용가능_CA        int64
#  7   회원여부_이용가능_카드론       int64
#  8   소지여부_신용             int64
#  9   소지카드수_유효_신용         int64
#  10  소지카드수_이용가능_신용       int64
#  11  입회일자_신용             int64
#  12  입회경과개월수_신용          int64
#  13  회원여부_연체             int64
#  14  이용거절여부_카드론          int64
#  15  동의여부_한도증액안내         int64
#  16  수신거부여부_TM           int64
#  17  수신거부여부_DM           int64
#  18  수신거부여부_메일           int64
#  19  수신거부여부_SMS          int64
#  20  가입통신회사코드            object
#  21  탈회횟수_누적             int64
#  22  최종탈회후경과월            int64
# ...

# %%
remove_cols = ['_2순위카드이용건수',
                  '소지여부_신용',
                  '제휴연회비_B0M',
                  '카드신청건수',
                  '우수회원면제카드수_B0M',
                  '유효카드수_신용_가족', 
                  '임직원면제카드수_B0M', 
                  '할인금액_제휴연회비_B0M', 
                  '회원여부_이용가능', 
                  '상품관련면제카드수_B0M',
                  '이용금액_R3M_체크',
                  '이용거절여부_카드론',
                  '청구금액_제휴연회비_B0M',
                  '_2순위카드이용금액',
                  '회원여부_연체',
                  '탈회횟수_발급1년이내',
                  '탈회횟수_발급6개월이내',
                  '이용금액_R3M_체크_가족',
                  '이용가능카드수_체크_가족',
                  '이용가능카드수_신용_가족',
                  '이용카드수_체크_가족',
                  '할인금액_기본연회비_B0M',
                  '유효카드수_체크_가족',
                  '이용카드수_신용_가족',
                  '기본연회비_B0M',
                  '기타면제카드수_B0M',
                  '이용금액_R3M_신용_가족',
                  '동의여부_한도증액안내',
                  '연회비할인카드수_B0M',
                  '청구금액_기본연회비_B0M',
                  '이용카드수_체크']

cleaned_df1 = merged_df.drop(remove_cols, axis=1)
cleaned_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 47 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   기준년월                int64
#  1   ID                  object
#  2   남녀구분코드              int64
#  3   연령                  object
#  4   Segment             object
#  5   회원여부_이용가능_CA        int64
#  6   회원여부_이용가능_카드론       int64
#  7   소지카드수_유효_신용         int64
#  8   소지카드수_이용가능_신용       int64
#  9   입회일자_신용             int64
#  10  입회경과개월수_신용          int64
#  11  수신거부여부_TM           int64
#  12  수신거부여부_DM           int64
#  13  수신거부여부_메일           int64
#  14  수신거부여부_SMS          int64
#  15  가입통신회사코드            object
#  16  탈회횟수_누적             int64
#  17  최종탈회후경과월            int64
#  18  거주시도명               object
#  19  직장시도명               object
#  20  마케팅동의여부             int64
#  21  유효카드수_신용체크          int64
#  22  유효카드수_신용            int64
#  23  유효카드수_체크            int64
# ...

# %%
a1 = cleaned_df1.columns.to_list()

for i in a1:
    print(f"{cleaned_df1[i].value_counts(dropna=False)}")
    print(f"Unique : {cleaned_df1[i].unique()}")
    print(f"남은 결측치 : {cleaned_df1[i].isnull().sum()}")
    print('----'*10)
# Out:
# 기준년월
# 201807    400000
# 201808    400000
# 201809    400000
# 201810    400000
# 201811    400000
# 201812    400000
# Name: count, dtype: int64
# Unique : [201807 201808 201809 201810 201811 201812]
# 남은 결측치 : 0
# ----------------------------------------
# ID
# TRAIN_000000    6
# TRAIN_266650    6
# TRAIN_266672    6
# TRAIN_266671    6
# TRAIN_266670    6
#                ..
# TRAIN_133331    6
# TRAIN_133330    6
# TRAIN_133329    6
# TRAIN_133328    6
# TRAIN_399999    6
# Name: count, Length: 400000, dtype: int64
# Unique : ['TRAIN_000000' 'TRAIN_000001' 'TRAIN_000002' ... 'TRAIN_399997'
#  'TRAIN_399998' 'TRAIN_399999']
# 남은 결측치 : 0
# ----------------------------------------
# 남녀구분코드
# 1    1255308
# 2    1144692
# Name: count, dtype: int64
# Unique : [2 1]
# 남은 결측치 : 0
# ----------------------------------------
# 연령
# 40대      733146
# 30대      592146
# 50대      546342
# 60대      246990
# 20대      191880
# 70대이상     89496
# Name: count, dtype: int64
# ...

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # 2. 신용정보

# %%
df1 = pd.read_parquet('../open/train/2.신용정보/201807_train_신용정보.parquet')
df2 = pd.read_parquet('../open/train/2.신용정보/201808_train_신용정보.parquet')
df3 = pd.read_parquet('../open/train/2.신용정보/201809_train_신용정보.parquet')
df4 = pd.read_parquet('../open/train/2.신용정보/201810_train_신용정보.parquet')
df5 = pd.read_parquet('../open/train/2.신용정보/201811_train_신용정보.parquet')
df6 = pd.read_parquet('../open/train/2.신용정보/201812_train_신용정보.parquet')


# 담을 리스트 리스트
all_df = []

# df1~6 담아주기
all_df.append(df1)
all_df.append(df2)
all_df.append(df3)
all_df.append(df4)
all_df.append(df5)
all_df.append(df6)

# merge
merged_df = pd.concat(all_df, ignore_index=True)

print("\n--- 데이터 기본 정보 ---")
merged_df.info()
print("\n")
merged_df.head()
# Out:
# --- 데이터 기본 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 42 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   기준년월            int64
#  1   ID              object
#  2   최초한도금액          int64
#  3   카드이용한도금액        int64
#  4   CA한도금액          int64
#  5   일시상환론한도금액       int64
#  6   월상환론한도금액        int64
#  7   CA이자율_할인전       float64
#  8   CL이자율_할인전       float64
#  9   RV일시불이자율_할인전    float64
#  10  RV현금서비스이자율_할인전  float64
#  11  RV신청일자          float64
#  12  RV약정청구율         float64
#  13  RV최소결제비율        float64
#  14  자발한도감액횟수_R12M   object
#  15  자발한도감액금액_R12M   int64
#  16  자발한도감액후경과월      int64
#  17  강제한도감액횟수_R12M   int64
#  18  강제한도감액금액_R12M   int64
#  19  강제한도감액후경과월      int64
#  20  한도증액횟수_R12M     object
#  21  한도증액금액_R12M     int64
#  22  한도증액후경과월        int64
#  23  상향가능한도금액        int64
#  24  상향가능CA한도금액      int64
#  25  카드론동의여부         object
#  26  월상환론상향가능한도금액    int64
# ...

# %%
remove_cols = ['월상환론상향가능한도금액',
               'RV신청일자',
               '시장단기연체여부_R3M',
               '시장연체상환여부_R3M',
               '특별한도보유여부_R3M',
               '한도요청거절건수',
               'RV약정청구율',
               '연체감액여부_R3M',
               '강제한도감액횟수_R12M',
               '최초한도금액',
               '한도심사요청후경과월',
               '한도심사거절후경과월',
               '강제한도감액금액_R12M',
               '시장연체상환여부_R6M',
               '시장단기연체여부_R6M',
               '자발한도감액금액_R12M',
               '한도증액금액_R12M',
               '자발한도감액후경과월']

cleaned_df2 = merged_df.drop(remove_cols, axis=1)
cleaned_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 24 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   기준년월            int64
#  1   ID              object
#  2   카드이용한도금액        int64
#  3   CA한도금액          int64
#  4   일시상환론한도금액       int64
#  5   월상환론한도금액        int64
#  6   CA이자율_할인전       float64
#  7   CL이자율_할인전       float64
#  8   RV일시불이자율_할인전    float64
#  9   RV현금서비스이자율_할인전  float64
#  10  RV최소결제비율        float64
#  11  자발한도감액횟수_R12M   object
#  12  강제한도감액후경과월      int64
#  13  한도증액횟수_R12M     object
#  14  한도증액후경과월        int64
#  15  상향가능한도금액        int64
#  16  상향가능CA한도금액      int64
#  17  카드론동의여부         object
#  18  RV전환가능여부        object
#  19  일시불ONLY전환가능여부   int64
#  20  카드이용한도금액_B1M    int64
#  21  카드이용한도금액_B2M    int64
#  22  한도심사요청건수        object
#  23  rv최초시작후경과일      int64
# dtypes: float64(5), int64(13), object(6)
# memory usage: 439.5+ MB

# %%
a1 = cleaned_df2.columns.to_list()

for i in a1:
    print(f"{cleaned_df2[i].value_counts(dropna=False)}")
    print(f"Unique : {cleaned_df2[i].unique()}")
    print(f"남은 결측치 : {cleaned_df2[i].isnull().sum()}")
    print('----'*10)
# Out:
# 기준년월
# 201807    400000
# 201808    400000
# 201809    400000
# 201810    400000
# 201811    400000
# 201812    400000
# Name: count, dtype: int64
# Unique : [201807 201808 201809 201810 201811 201812]
# 남은 결측치 : 0
# ----------------------------------------
# ID
# TRAIN_000000    6
# TRAIN_266650    6
# TRAIN_266672    6
# TRAIN_266671    6
# TRAIN_266670    6
#                ..
# TRAIN_133331    6
# TRAIN_133330    6
# TRAIN_133329    6
# TRAIN_133328    6
# TRAIN_399999    6
# Name: count, Length: 400000, dtype: int64
# Unique : ['TRAIN_000000' 'TRAIN_000001' 'TRAIN_000002' ... 'TRAIN_399997'
#  'TRAIN_399998' 'TRAIN_399999']
# 남은 결측치 : 0
# ----------------------------------------
# 카드이용한도금액
# 0         98003
# 9999      37990
# 10000     37990
# 9998      33190
# 10001     32356
#           ...
# 213480        1
# 219823        1
# 16078         1
# 205989        1
# 176500        1
# Name: count, Length: 81852, dtype: int64
# ...

# %%
10/0

# %% [markdown]
# # 5. 잔액정보

# %%
df1 = pd.read_parquet('../open/train/5.잔액정보/201807_train_잔액정보.parquet')
df2 = pd.read_parquet('../open/train/5.잔액정보/201808_train_잔액정보.parquet')
df3 = pd.read_parquet('../open/train/5.잔액정보/201809_train_잔액정보.parquet')
df4 = pd.read_parquet('../open/train/5.잔액정보/201810_train_잔액정보.parquet')
df5 = pd.read_parquet('../open/train/5.잔액정보/201811_train_잔액정보.parquet')
df6 = pd.read_parquet('../open/train/5.잔액정보/201812_train_잔액정보.parquet')


# 담을 리스트 리스트
all_df = []

# df1~6 담아주기
all_df.append(df1)
all_df.append(df2)
all_df.append(df3)
all_df.append(df4)
all_df.append(df5)
all_df.append(df6)

# merge
merged_df = pd.concat(all_df, ignore_index=True)

print("\n--- 데이터 기본 정보 ---")
merged_df.info()
print("\n")
merged_df.head()
# Out:
# --- 데이터 기본 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 82 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   기준년월               int64
#  1   ID                 object
#  2   잔액_일시불_B0M         int64
#  3   잔액_할부_B0M          int64
#  4   잔액_현금서비스_B0M       int64
#  5   잔액_리볼빙일시불이월_B0M    int64
#  6   잔액_리볼빙CA이월_B0M     int64
#  7   잔액_카드론_B0M         int64
#  8   월중평잔_일시불_B0M       int64
#  9   월중평잔_할부_B0M        int64
#  10  월중평잔_CA_B0M        int64
#  11  카드론잔액_최종경과월        int64
#  12  연체일자_B0M           float64
#  13  연체잔액_B0M           int64
#  14  연체잔액_일시불_B0M       int64
#  15  연체잔액_할부_B0M        int64
#  16  연체잔액_현금서비스_B0M     int64
#  17  연체잔액_카드론_B0M       int64
#  18  연체잔액_대환론_B0M       int64
#  19  잔액_현금서비스_B1M       int64
#  20  잔액_현금서비스_B2M       int64
#  21  잔액_카드론_B1M         int64
#  22  잔액_카드론_B2M         int64
#  23  잔액_카드론_B3M         int64
# ...

# %%
remove_cols = [
'잔액_현금서비스_B0M',
'잔액_리볼빙일시불이월_B0M',
'잔액_리볼빙CA이월_B0M',
'잔액_카드론_B0M',
'월중평잔_CA_B0M',
'카드론잔액_최종경과월',
'연체일자_B0M',
'연체잔액_B0M',
'연체잔액_일시불_B0M',
'연체잔액_할부_B0M',
'연체잔액_현금서비스_B0M',
'연체잔액_카드론_B0M',
'연체잔액_대환론_B0M',
'잔액_현금서비스_B1M',
'잔액_현금서비스_B2M',
'잔액_카드론_B1M',
'잔액_카드론_B2M',
'잔액_카드론_B3M',
'잔액_카드론_B4M',
'잔액_카드론_B5M',
'연체원금_B1M',
'연체원금_B2M',
'연체원금_최근',
'매각잔액_B1M',
'최종연체개월수_R15M',
'RV_평균잔액_R12M',
'RV_최대잔액_R12M',
'RV_평균잔액_R6M',
'RV_최대잔액_R6M',
'RV_평균잔액_R3M',
'RV_최대잔액_R3M',
'RV잔액이월횟수_R6M',
'RV잔액이월횟수_R3M',
'잔액_할부_유이자_B0M',
'잔액_할부_해외_B0M',
'연체잔액_일시불_해외_B0M',
'연체잔액_RV일시불_B0M',
'연체잔액_RV일시불_해외_B0M',
'연체잔액_할부_해외_B0M',
'연체잔액_CA_B0M',
'연체잔액_CA_해외_B0M',
'월중평잔_RV일시불',
'월중평잔_CA',
'월중평잔_카드론',
'평잔_일시불_해외_3M',
'평잔_RV일시불_3M',
'평잔_RV일시불_해외_3M',
'평잔_할부_해외_3M',
'평잔_CA_3M',
'평잔_CA_해외_3M',
'평잔_카드론_3M',
'평잔_일시불_해외_6M',
'평잔_RV일시불_6M',
'평잔_RV일시불_해외_6M',
'평잔_할부_해외_6M',
'평잔_CA_6M',
'평잔_CA_해외_6M',
'평잔_카드론_6M']
cleaned_df3 = merged_df.drop(remove_cols, axis=1)
cleaned_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 24 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   기준년월           int64
#  1   ID             object
#  2   잔액_일시불_B0M     int64
#  3   잔액_할부_B0M      int64
#  4   월중평잔_일시불_B0M   int64
#  5   월중평잔_할부_B0M    int64
#  6   잔액_할부_B1M      int64
#  7   잔액_할부_B2M      int64
#  8   잔액_일시불_B1M     int64
#  9   잔액_일시불_B2M     int64
#  10  연체일수_B1M       int64
#  11  연체일수_B2M       int64
#  12  연체일수_최근        int64
#  13  최종연체회차         int64
#  14  잔액_할부_무이자_B0M  int64
#  15  월중평잔           int64
#  16  월중평잔_일시불       int64
#  17  월중평잔_할부        int64
#  18  평잔_3M          int64
#  19  평잔_일시불_3M      int64
#  20  평잔_할부_3M       int64
#  21  평잔_6M          int64
#  22  평잔_일시불_6M      int64
#  23  평잔_할부_6M       int64
# dtypes: int64(23), object(1)
# memory usage: 439.5+ MB

# %%
a1 = cleaned_df3.columns.to_list()

for i in a1:
    print(f"{cleaned_df3[i].value_counts(dropna=False)}")
    print(f"Unique : {cleaned_df3[i].unique()}")
    print(f"Dtype : {cleaned_df3[i].dtype}")
    print(f"남은 결측치 : {cleaned_df3[i].isnull().sum()}")
    print('----'*10)
    print()
# Out:
# 기준년월
# 201807    400000
# 201808    400000
# 201809    400000
# 201810    400000
# 201811    400000
# 201812    400000
# Name: count, dtype: int64
# Unique : [201807 201808 201809 201810 201811 201812]
# Dtype : int64
# 남은 결측치 : 0
# ----------------------------------------
#
# ID
# TRAIN_000000    6
# TRAIN_266650    6
# TRAIN_266672    6
# TRAIN_266671    6
# TRAIN_266670    6
#                ..
# TRAIN_133331    6
# TRAIN_133330    6
# TRAIN_133329    6
# TRAIN_133328    6
# TRAIN_399999    6
# Name: count, Length: 400000, dtype: int64
# Unique : ['TRAIN_000000' 'TRAIN_000001' 'TRAIN_000002' ... 'TRAIN_399997'
#  'TRAIN_399998' 'TRAIN_399999']
# Dtype : object
# 남은 결측치 : 0
# ----------------------------------------
#
# 잔액_일시불_B0M
# 0         684962
# 7           1270
# 8           1240
# 9           1112
# 10           968
#            ...
# 33163          1
# 41698          1
# 40967          1
# 164026         1
# 23438          1
# Name: count, Length: 46915, dtype: int64
# ...
